# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy
from config import weather_api_key
from config import weather_api_host

# %%
#Create a set of 2,000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 748

# %%
#Import dependencies
import requests
from config import weather_api_key

url = weather_api_host + "?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city  in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | hermanus
# Processing Record 3 of Set 1 | sioux lookout
# Processing Record 4 of Set 1 | cape town
# Processing Record 5 of Set 1 | margate
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | batsfjord
# Processing Record 9 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 1 | port alfred
# Processing Record 11 of Set 1 | makakilo city
# Processing Record 12 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 1 | trebinje
# Processing Record 14 of Set 1 | kotelnich
# Processing Record 15 of Set 1 | matagami
# Processing Record 16 of Set 1 | norman wells
# Processing Record 17 of Set 1 | mar del plata
# Processing Record 18 of Set 1 | jamestown
# Processing Record 19 of Set 1 | hobart
# Processing Record 20 of Set 1 | tasiilaq
# Processing Record 21 of Set 1 | takoradi
# Processing Record 22 of Set 1 | tuatapere
# Processing Record 23 of Set 1 | nador
# Processing Record 24 of Set 1 | kinablangan
# Processing Record 25 of Set 1 | chuy
# Processing Record 26 of Set 1 | acapulco
# Processing Record 27 of Set 1 | sinkat
# City not found. Skipping...
# Processing Record 28 of Set 1 | charters towers
# Processing Record 29 of Set 1 | saint-georges
# Processing Record 30 of Set 1 | boma
# Processing Record 31 of Set 1 | kapaa
# Processing Record 32 of Set 1 | vaini
# Processing Record 33 of Set 1 | garwa
# Processing Record 34 of Set 1 | bethel
# Processing Record 35 of Set 1 | mount gambier
# Processing Record 36 of Set 1 | kaitangata
# Processing Record 37 of Set 1 | padang
# Processing Record 38 of Set 1 | hamilton
# Processing Record 39 of Set 1 | faanui
# Processing Record 40 of Set 1 | mahebourg
# Processing Record 41 of Set 1 | albany
# Processing Record 42 of Set 1 | uusikaupunki
# Processing Record 43 of Set 1 | rikitea
# Processing Record 44 of Set 1 | bilibino
# Processing Record 45 of Set 1 | avarua
# Processing Record 46 of Set 1 | nikolskoye
# Processing Record 47 of Set 1 | turukhansk
# Processing Record 48 of Set 1 | bengkulu
# Processing Record 49 of Set 1 | panormos
# Processing Record 50 of Set 1 | nakamura
# Processing Record 1 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 2 | manali
# Processing Record 3 of Set 2 | sechura
# Processing Record 4 of Set 2 | bambanglipuro
# Processing Record 5 of Set 2 | vanimo
# Processing Record 6 of Set 2 | saldanha
# Processing Record 7 of Set 2 | kodiak
# Processing Record 8 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 2 | bambous virieux
# Processing Record 10 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 2 | barrow
# Processing Record 12 of Set 2 | muborak
# Processing Record 13 of Set 2 | ginir
# Processing Record 14 of Set 2 | busselton
# Processing Record 15 of Set 2 | port lincoln
# Processing Record 16 of Set 2 | kavaratti
# Processing Record 17 of Set 2 | kyren
# Processing Record 18 of Set 2 | bredasdorp
# Processing Record 19 of Set 2 | yumen
# Processing Record 20 of Set 2 | ouallam
# Processing Record 21 of Set 2 | shimoda
# Processing Record 22 of Set 2 | mayumba
# Processing Record 23 of Set 2 | nanortalik
# Processing Record 24 of Set 2 | severo-kurilsk
# Processing Record 25 of Set 2 | bac lieu
# Processing Record 26 of Set 2 | san carlos de bariloche
# Processing Record 27 of Set 2 | yevlax
# Processing Record 28 of Set 2 | airai
# Processing Record 29 of Set 2 | road town
# Processing Record 30 of Set 2 | sotouboua
# Processing Record 31 of Set 2 | goderich
# Processing Record 32 of Set 2 | khani
# Processing Record 33 of Set 2 | arona
# Processing Record 34 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 35 of Set 2 | ravar
# Processing Record 36 of Set 2 | conselheiro pena
# Processing Record 37 of Set 2 | salta
# Processing Record 38 of Set 2 | soyo
# Processing Record 39 of Set 2 | aswan
# Processing Record 40 of Set 2 | hithadhoo
# Processing Record 41 of Set 2 | saint-philippe
# Processing Record 42 of Set 2 | cherskiy
# Processing Record 43 of Set 2 | asyut
# Processing Record 44 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 45 of Set 2 | port shepstone
# Processing Record 46 of Set 2 | awjilah
# Processing Record 47 of Set 2 | poum
# Processing Record 48 of Set 2 | constitucion
# Processing Record 49 of Set 2 | veraval
# Processing Record 50 of Set 2 | maebaru
# Processing Record 1 of Set 3 | pisco
# Processing Record 2 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 3 of Set 3 | puerto escondido
# Processing Record 4 of Set 3 | rio gallegos
# Processing Record 5 of Set 3 | havelock
# Processing Record 6 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 3 | maragogi
# Processing Record 8 of Set 3 | prince rupert
# Processing Record 9 of Set 3 | ambilobe
# Processing Record 10 of Set 3 | katsuura
# Processing Record 11 of Set 3 | atuona
# Processing Record 12 of Set 3 | puerto ayora
# Processing Record 13 of Set 3 | cabo san lucas
# Processing Record 14 of Set 3 | tuggurt
# City not found. Skipping...
# Processing Record 15 of Set 3 | asfi
# Processing Record 16 of Set 3 | qaqortoq
# Processing Record 17 of Set 3 | marzuq
# Processing Record 18 of Set 3 | quelimane
# Processing Record 19 of Set 3 | kahului
# Processing Record 20 of Set 3 | upernavik
# Processing Record 21 of Set 3 | sisimiut
# Processing Record 22 of Set 3 | kahramanmaras
# Processing Record 23 of Set 3 | castro
# Processing Record 24 of Set 3 | sadovoye
# Processing Record 25 of Set 3 | arraial do cabo
# Processing Record 26 of Set 3 | huarmey
# Processing Record 27 of Set 3 | atherton
# Processing Record 28 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 3 | lavrentiya
# Processing Record 30 of Set 3 | novyy urengoy
# Processing Record 31 of Set 3 | hoa binh
# Processing Record 32 of Set 3 | nizhyn
# Processing Record 33 of Set 3 | taksimo
# Processing Record 34 of Set 3 | port-cartier
# Processing Record 35 of Set 3 | villa oliva
# City not found. Skipping...
# Processing Record 36 of Set 3 | butaritari
# Processing Record 37 of Set 3 | saint-leu
# Processing Record 38 of Set 3 | carnarvon
# Processing Record 39 of Set 3 | khatanga
# Processing Record 40 of Set 3 | ponta do sol
# Processing Record 41 of Set 3 | nouadhibou
# Processing Record 42 of Set 3 | bluff
# Processing Record 43 of Set 3 | plettenberg bay
# Processing Record 44 of Set 3 | tiksi
# Processing Record 45 of Set 3 | kimparana
# Processing Record 46 of Set 3 | ahuimanu
# Processing Record 47 of Set 3 | neiafu
# Processing Record 48 of Set 3 | provideniya
# Processing Record 49 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 50 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 1 of Set 4 | kruisfontein
# Processing Record 2 of Set 4 | rawannawi
# City not found. Skipping...
# Processing Record 3 of Set 4 | shitanjing
# Processing Record 4 of Set 4 | vila franca do campo
# Processing Record 5 of Set 4 | brownsville
# Processing Record 6 of Set 4 | dawlatabad
# Processing Record 7 of Set 4 | clyde river
# Processing Record 8 of Set 4 | ust-ilimsk
# Processing Record 9 of Set 4 | tuktoyaktuk
# Processing Record 10 of Set 4 | belturbet
# Processing Record 11 of Set 4 | emerald
# Processing Record 12 of Set 4 | deniliquin
# Processing Record 13 of Set 4 | okato
# Processing Record 14 of Set 4 | alice springs
# Processing Record 15 of Set 4 | san pedro
# Processing Record 16 of Set 4 | luderitz
# Processing Record 17 of Set 4 | ilulissat
# Processing Record 18 of Set 4 | saint-pierre
# Processing Record 19 of Set 4 | east london
# Processing Record 20 of Set 4 | araripina
# Processing Record 21 of Set 4 | dikson
# Processing Record 22 of Set 4 | yellowknife
# Processing Record 23 of Set 4 | zhigansk
# Processing Record 24 of Set 4 | waitara
# Processing Record 25 of Set 4 | high river
# Processing Record 26 of Set 4 | coihaique
# Processing Record 27 of Set 4 | sola
# Processing Record 28 of Set 4 | alofi
# Processing Record 29 of Set 4 | khandyga
# Processing Record 30 of Set 4 | isangel
# Processing Record 31 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 4 | vardo
# Processing Record 33 of Set 4 | tilichiki
# Processing Record 34 of Set 4 | teguldet
# Processing Record 35 of Set 4 | kuryk
# Processing Record 36 of Set 4 | lukow
# Processing Record 37 of Set 4 | ferme-neuve
# Processing Record 38 of Set 4 | yulara
# Processing Record 39 of Set 4 | kendari
# Processing Record 40 of Set 4 | hasaki
# Processing Record 41 of Set 4 | leningradskiy
# Processing Record 42 of Set 4 | hilo
# Processing Record 43 of Set 4 | cidreira
# Processing Record 44 of Set 4 | panambi
# Processing Record 45 of Set 4 | praya
# Processing Record 46 of Set 4 | luza
# Processing Record 47 of Set 4 | new norfolk
# Processing Record 48 of Set 4 | honningsvag
# Processing Record 49 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 50 of Set 4 | longyearbyen
# Processing Record 1 of Set 5 | fortuna
# Processing Record 2 of Set 5 | esperance
# Processing Record 3 of Set 5 | bathsheba
# Processing Record 4 of Set 5 | codrington
# Processing Record 5 of Set 5 | victoria
# Processing Record 6 of Set 5 | valenca
# Processing Record 7 of Set 5 | siocon
# Processing Record 8 of Set 5 | alekseyevsk
# Processing Record 9 of Set 5 | ancud
# Processing Record 10 of Set 5 | bilma
# Processing Record 11 of Set 5 | amboasary
# Processing Record 12 of Set 5 | sur
# Processing Record 13 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 14 of Set 5 | karamay
# City not found. Skipping...
# Processing Record 15 of Set 5 | high rock
# Processing Record 16 of Set 5 | rio grande
# Processing Record 17 of Set 5 | ribeira grande
# Processing Record 18 of Set 5 | sebaste
# Processing Record 19 of Set 5 | hami
# Processing Record 20 of Set 5 | albanel
# Processing Record 21 of Set 5 | tramandai
# Processing Record 22 of Set 5 | chitral
# Processing Record 23 of Set 5 | aquiraz
# Processing Record 24 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 25 of Set 5 | ayorou
# Processing Record 26 of Set 5 | yar-sale
# Processing Record 27 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 28 of Set 5 | whitehorse
# Processing Record 29 of Set 5 | galveston
# Processing Record 30 of Set 5 | fort saint john
# City not found. Skipping...
# Processing Record 31 of Set 5 | bjorkelangen
# Processing Record 32 of Set 5 | waipawa
# Processing Record 33 of Set 5 | sarangani
# Processing Record 34 of Set 5 | key west
# Processing Record 35 of Set 5 | mount isa
# Processing Record 36 of Set 5 | viedma
# Processing Record 37 of Set 5 | filingue
# Processing Record 38 of Set 5 | los llanos de aridane
# Processing Record 39 of Set 5 | lander
# Processing Record 40 of Set 5 | kumluca
# Processing Record 41 of Set 5 | kotelnikovo
# Processing Record 42 of Set 5 | husavik
# Processing Record 43 of Set 5 | khormuj
# City not found. Skipping...
# Processing Record 44 of Set 5 | saskylakh
# Processing Record 45 of Set 5 | kitimat
# Processing Record 46 of Set 5 | zhangjiakou
# Processing Record 47 of Set 5 | nelson
# Processing Record 48 of Set 5 | okmulgee
# Processing Record 49 of Set 5 | manado
# Processing Record 50 of Set 5 | oistins
# Processing Record 1 of Set 6 | jiazi
# Processing Record 2 of Set 6 | kropotkin
# Processing Record 3 of Set 6 | itarema
# Processing Record 4 of Set 6 | forestville
# Processing Record 5 of Set 6 | ouadda
# Processing Record 6 of Set 6 | raudeberg
# Processing Record 7 of Set 6 | laguna
# Processing Record 8 of Set 6 | paso de los toros
# Processing Record 9 of Set 6 | sao filipe
# Processing Record 10 of Set 6 | souillac
# Processing Record 11 of Set 6 | geraldton
# Processing Record 12 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 13 of Set 6 | safaga
# Processing Record 14 of Set 6 | westport
# Processing Record 15 of Set 6 | chapais
# Processing Record 16 of Set 6 | luanda
# Processing Record 17 of Set 6 | yarkovo
# Processing Record 18 of Set 6 | point fortin
# Processing Record 19 of Set 6 | casian
# Processing Record 20 of Set 6 | jaegerspris
# Processing Record 21 of Set 6 | royal leamington spa
# Processing Record 22 of Set 6 | sao jose da coroa grande
# Processing Record 23 of Set 6 | ixtapa
# Processing Record 24 of Set 6 | sakakah
# Processing Record 25 of Set 6 | katobu
# Processing Record 26 of Set 6 | san julian
# Processing Record 27 of Set 6 | lasem
# Processing Record 28 of Set 6 | pitea
# Processing Record 29 of Set 6 | iqaluit
# Processing Record 30 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 6 | srandakan
# Processing Record 32 of Set 6 | pilar
# Processing Record 33 of Set 6 | gualaquiza
# Processing Record 34 of Set 6 | qaanaaq
# Processing Record 35 of Set 6 | georgetown
# Processing Record 36 of Set 6 | sao joao da barra
# Processing Record 37 of Set 6 | mosquera
# Processing Record 38 of Set 6 | kaeo
# Processing Record 39 of Set 6 | zelenoborsk
# Processing Record 40 of Set 6 | coquimbo
# Processing Record 41 of Set 6 | bhigvan
# Processing Record 42 of Set 6 | te anau
# Processing Record 43 of Set 6 | mayo
# Processing Record 44 of Set 6 | sundumbili
# Processing Record 45 of Set 6 | centralia
# Processing Record 46 of Set 6 | marystown
# Processing Record 47 of Set 6 | batticaloa
# Processing Record 48 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of Set 6 | verkhnyaya inta
# Processing Record 50 of Set 6 | celestun
# Processing Record 1 of Set 7 | colquiri
# Processing Record 2 of Set 7 | thompson
# Processing Record 3 of Set 7 | jalu
# Processing Record 4 of Set 7 | sterling
# Processing Record 5 of Set 7 | kavieng
# Processing Record 6 of Set 7 | aklavik
# Processing Record 7 of Set 7 | saint george
# Processing Record 8 of Set 7 | jepelacio
# Processing Record 9 of Set 7 | krasnoselkup
# Processing Record 10 of Set 7 | lagoa
# Processing Record 11 of Set 7 | touros
# Processing Record 12 of Set 7 | ussel
# Processing Record 13 of Set 7 | ziro
# Processing Record 14 of Set 7 | atka
# City not found. Skipping...
# Processing Record 15 of Set 7 | portland
# Processing Record 16 of Set 7 | manta
# Processing Record 17 of Set 7 | batemans bay
# Processing Record 18 of Set 7 | zalesovo
# Processing Record 19 of Set 7 | sobolevo
# Processing Record 20 of Set 7 | barra do bugres
# Processing Record 21 of Set 7 | galiwinku
# City not found. Skipping...
# Processing Record 22 of Set 7 | lebu
# Processing Record 23 of Set 7 | port elizabeth
# Processing Record 24 of Set 7 | haines junction
# Processing Record 25 of Set 7 | dzerzhinskoye
# Processing Record 26 of Set 7 | zwedru
# Processing Record 27 of Set 7 | xingyi
# Processing Record 28 of Set 7 | meadow lake
# Processing Record 29 of Set 7 | muroto
# Processing Record 30 of Set 7 | hambantota
# Processing Record 31 of Set 7 | solnechnyy
# Processing Record 32 of Set 7 | noumea
# Processing Record 33 of Set 7 | machaneng
# Processing Record 34 of Set 7 | buchanan
# Processing Record 35 of Set 7 | novo aripuana
# Processing Record 36 of Set 7 | sorong
# Processing Record 37 of Set 7 | nova petropolis
# Processing Record 38 of Set 7 | seoul
# Processing Record 39 of Set 7 | ostrovnoy
# Processing Record 40 of Set 7 | sayyan
# Processing Record 41 of Set 7 | pangnirtung
# Processing Record 42 of Set 7 | rumonge
# Processing Record 43 of Set 7 | waddan
# Processing Record 44 of Set 7 | belmonte
# Processing Record 45 of Set 7 | querecotillo
# Processing Record 46 of Set 7 | coos bay
# Processing Record 47 of Set 7 | borova
# Processing Record 48 of Set 7 | dinard
# Processing Record 49 of Set 7 | tenenkou
# Processing Record 50 of Set 7 | caravelas
# Processing Record 1 of Set 8 | dauphin
# Processing Record 2 of Set 8 | hermiston
# Processing Record 3 of Set 8 | manzanillo
# Processing Record 4 of Set 8 | sens
# Processing Record 5 of Set 8 | lasa
# Processing Record 6 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 7 of Set 8 | hachinohe
# Processing Record 8 of Set 8 | ayagoz
# Processing Record 9 of Set 8 | gunjur
# Processing Record 10 of Set 8 | cururupu
# Processing Record 11 of Set 8 | sabla
# Processing Record 12 of Set 8 | nizhniy kuranakh
# Processing Record 13 of Set 8 | port hawkesbury
# Processing Record 14 of Set 8 | grindavik
# Processing Record 15 of Set 8 | gizo
# Processing Record 16 of Set 8 | narsaq
# Processing Record 17 of Set 8 | fukue
# Processing Record 18 of Set 8 | wukari
# Processing Record 19 of Set 8 | mezhevoy
# Processing Record 20 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 21 of Set 8 | gardez
# Processing Record 22 of Set 8 | tabas
# Processing Record 23 of Set 8 | marawi
# Processing Record 24 of Set 8 | uniontown
# Processing Record 25 of Set 8 | tatawin
# Processing Record 26 of Set 8 | kawardha
# Processing Record 27 of Set 8 | bentiu
# Processing Record 28 of Set 8 | sungaipenuh
# Processing Record 29 of Set 8 | luena
# Processing Record 30 of Set 8 | ballina
# Processing Record 31 of Set 8 | bage
# Processing Record 32 of Set 8 | vuktyl
# Processing Record 33 of Set 8 | evensk
# Processing Record 34 of Set 8 | kloulklubed
# Processing Record 35 of Set 8 | tieling
# Processing Record 36 of Set 8 | auki
# Processing Record 37 of Set 8 | talnakh
# Processing Record 38 of Set 8 | cedral
# Processing Record 39 of Set 8 | barroualie
# City not found. Skipping...
# Processing Record 40 of Set 8 | pandan
# Processing Record 41 of Set 8 | agnibilekrou
# Processing Record 42 of Set 8 | scottsburgh
# City not found. Skipping...
# Processing Record 43 of Set 8 | qasigiannguit
# Processing Record 44 of Set 8 | ambodifototra
# City not found. Skipping...
# Processing Record 45 of Set 8 | effium
# Processing Record 46 of Set 8 | pangkalanbuun
# Processing Record 47 of Set 8 | sao felix do xingu
# Processing Record 48 of Set 8 | lorengau
# Processing Record 49 of Set 8 | chavakkad
# Processing Record 50 of Set 8 | puerto madryn
# Processing Record 1 of Set 9 | sorland
# Processing Record 2 of Set 9 | korla
# Processing Record 3 of Set 9 | lubango
# Processing Record 4 of Set 9 | tukrah
# Processing Record 5 of Set 9 | labutta
# City not found. Skipping...
# Processing Record 6 of Set 9 | balsas
# Processing Record 7 of Set 9 | wilhelmsburg
# Processing Record 8 of Set 9 | mugur-aksy
# Processing Record 9 of Set 9 | lakes entrance
# Processing Record 10 of Set 9 | san patricio
# Processing Record 11 of Set 9 | osakarovka
# Processing Record 12 of Set 9 | sinnamary
# Processing Record 13 of Set 9 | sovetskaya gavan
# Processing Record 14 of Set 9 | nkowakowa
# Processing Record 15 of Set 9 | abu kamal
# Processing Record 16 of Set 9 | tawnat
# City not found. Skipping...
# Processing Record 17 of Set 9 | tawkar
# City not found. Skipping...
# Processing Record 18 of Set 9 | necochea
# Processing Record 19 of Set 9 | zeya
# Processing Record 20 of Set 9 | west lafayette
# Processing Record 21 of Set 9 | baturinskaya
# Processing Record 22 of Set 9 | mildura
# Processing Record 23 of Set 9 | yabelo
# Processing Record 24 of Set 9 | fare
# Processing Record 25 of Set 9 | pevek
# Processing Record 26 of Set 9 | osoyoos
# Processing Record 27 of Set 9 | ulundi
# Processing Record 28 of Set 9 | faya
# Processing Record 29 of Set 9 | torbay
# Processing Record 30 of Set 9 | klaksvik
# Processing Record 31 of Set 9 | labytnangi
# Processing Record 32 of Set 9 | lompoc
# Processing Record 33 of Set 9 | knysna
# Processing Record 34 of Set 9 | swan hill
# Processing Record 35 of Set 9 | bintulu
# Processing Record 36 of Set 9 | faranah
# Processing Record 37 of Set 9 | skjervoy
# Processing Record 38 of Set 9 | vestmannaeyjar
# Processing Record 39 of Set 9 | shubarkuduk
# Processing Record 40 of Set 9 | beyla
# Processing Record 41 of Set 9 | cockburn harbour
# City not found. Skipping...
# Processing Record 42 of Set 9 | beringovskiy
# Processing Record 43 of Set 9 | port pirie
# Processing Record 44 of Set 9 | metro
# Processing Record 45 of Set 9 | tsienyane
# City not found. Skipping...
# Processing Record 46 of Set 9 | mackay
# Processing Record 47 of Set 9 | ipixuna
# Processing Record 48 of Set 9 | kapuskasing
# Processing Record 49 of Set 9 | mecca
# Processing Record 50 of Set 9 | kidal
# Processing Record 1 of Set 10 | naze
# Processing Record 2 of Set 10 | sambava
# Processing Record 3 of Set 10 | skalistyy
# City not found. Skipping...
# Processing Record 4 of Set 10 | santa rosa
# Processing Record 5 of Set 10 | inza
# Processing Record 6 of Set 10 | tallahassee
# Processing Record 7 of Set 10 | dalnerechensk
# Processing Record 8 of Set 10 | la ronge
# Processing Record 9 of Set 10 | kieta
# Processing Record 10 of Set 10 | vostok
# Processing Record 11 of Set 10 | mersin
# Processing Record 12 of Set 10 | cumaribo
# City not found. Skipping...
# Processing Record 13 of Set 10 | lebedinyy
# Processing Record 14 of Set 10 | nantucket
# Processing Record 15 of Set 10 | zarubino
# Processing Record 16 of Set 10 | shemysheyka
# Processing Record 17 of Set 10 | petatlan
# Processing Record 18 of Set 10 | maceio
# Processing Record 19 of Set 10 | manokwari
# Processing Record 20 of Set 10 | lagos
# Processing Record 21 of Set 10 | temaraia
# City not found. Skipping...
# Processing Record 22 of Set 10 | taoudenni
# Processing Record 23 of Set 10 | half moon bay
# Processing Record 24 of Set 10 | ahipara
# Processing Record 25 of Set 10 | yinchuan
# Processing Record 26 of Set 10 | poso
# Processing Record 27 of Set 10 | eyl
# Processing Record 28 of Set 10 | cermik
# Processing Record 29 of Set 10 | aldan
# Processing Record 30 of Set 10 | assai
# Processing Record 31 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 32 of Set 10 | komsomolskiy
# Processing Record 33 of Set 10 | nacala
# Processing Record 34 of Set 10 | jiuquan
# Processing Record 35 of Set 10 | agua dulce
# Processing Record 36 of Set 10 | port hardy
# Processing Record 37 of Set 10 | champerico
# Processing Record 38 of Set 10 | hunza
# City not found. Skipping...
# Processing Record 39 of Set 10 | russell
# Processing Record 40 of Set 10 | byron bay
# Processing Record 41 of Set 10 | chara
# Processing Record 42 of Set 10 | suicheng
# Processing Record 43 of Set 10 | san quintin
# Processing Record 44 of Set 10 | tabarqah
# City not found. Skipping...
# Processing Record 45 of Set 10 | olivenza
# Processing Record 46 of Set 10 | novikovo
# Processing Record 47 of Set 10 | dubai
# Processing Record 48 of Set 10 | kadoma
# Processing Record 49 of Set 10 | sitka
# Processing Record 50 of Set 10 | miyako
# Processing Record 1 of Set 11 | apatity
# Processing Record 2 of Set 11 | gurupa
# Processing Record 3 of Set 11 | buala
# Processing Record 4 of Set 11 | rawson
# Processing Record 5 of Set 11 | yorii
# Processing Record 6 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 7 of Set 11 | guerrero negro
# Processing Record 8 of Set 11 | kawalu
# Processing Record 9 of Set 11 | tupik
# Processing Record 10 of Set 11 | lima
# Processing Record 11 of Set 11 | rudbar
# Processing Record 12 of Set 11 | coruripe
# Processing Record 13 of Set 11 | sovetskiy
# Processing Record 14 of Set 11 | banda aceh
# Processing Record 15 of Set 11 | warrington
# Processing Record 16 of Set 11 | bonoua
# Processing Record 17 of Set 11 | ambon
# Processing Record 18 of Set 11 | mandalgovi
# Processing Record 19 of Set 11 | buraydah
# Processing Record 20 of Set 11 | fuyu
# Processing Record 21 of Set 11 | quatre cocos
# Processing Record 22 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 23 of Set 11 | miles city
# Processing Record 24 of Set 11 | thunder bay
# Processing Record 25 of Set 11 | ucluelet
# Processing Record 26 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 27 of Set 11 | lake charles
# Processing Record 28 of Set 11 | marang
# Processing Record 29 of Set 11 | xichang
# Processing Record 30 of Set 11 | saurimo
# Processing Record 31 of Set 11 | bubaque
# Processing Record 32 of Set 11 | leh
# Processing Record 33 of Set 11 | omsukchan
# Processing Record 34 of Set 11 | vengerovo
# Processing Record 35 of Set 11 | cabedelo
# Processing Record 36 of Set 11 | dunmore town
# Processing Record 37 of Set 11 | seymchan
# Processing Record 38 of Set 11 | mishkino
# Processing Record 39 of Set 11 | pocatello
# Processing Record 40 of Set 11 | reporoa
# Processing Record 41 of Set 11 | emba
# Processing Record 42 of Set 11 | mitsamiouli
# Processing Record 43 of Set 11 | saco
# Processing Record 44 of Set 11 | oranjemund
# Processing Record 45 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 46 of Set 11 | ozinki
# Processing Record 47 of Set 11 | lufilufi
# Processing Record 48 of Set 11 | motygino
# Processing Record 49 of Set 11 | chokurdakh
# Processing Record 50 of Set 11 | kununurra
# Processing Record 1 of Set 12 | goundam
# Processing Record 2 of Set 12 | stephenville
# Processing Record 3 of Set 12 | alghero
# Processing Record 4 of Set 12 | ponta delgada
# Processing Record 5 of Set 12 | bembereke
# Processing Record 6 of Set 12 | tres arroyos
# Processing Record 7 of Set 12 | yaan
# Processing Record 8 of Set 12 | vilani
# Processing Record 9 of Set 12 | voyvozh
# Processing Record 10 of Set 12 | najran
# Processing Record 11 of Set 12 | shestakovo
# Processing Record 12 of Set 12 | flinders
# Processing Record 13 of Set 12 | nago
# Processing Record 14 of Set 12 | havre-saint-pierre
# Processing Record 15 of Set 12 | henties bay
# Processing Record 16 of Set 12 | khor
# Processing Record 17 of Set 12 | severomuysk
# Processing Record 18 of Set 12 | severnyy-kospashskiy
# Processing Record 19 of Set 12 | pedasi
# Processing Record 20 of Set 12 | lodja
# Processing Record 21 of Set 12 | kattivakkam
# Processing Record 22 of Set 12 | santa barbara
# Processing Record 23 of Set 12 | aanekoski
# Processing Record 24 of Set 12 | parrita
# Processing Record 25 of Set 12 | pacific grove
# Processing Record 26 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 27 of Set 12 | tsiroanomandidy
# Processing Record 28 of Set 12 | biak
# Processing Record 29 of Set 12 | waingapu
# Processing Record 30 of Set 12 | thinadhoo
# Processing Record 31 of Set 12 | bontang
# Processing Record 32 of Set 12 | mount hagen
# Processing Record 33 of Set 12 | dalvik
# Processing Record 34 of Set 12 | obera
# Processing Record 35 of Set 12 | gigmoto
# Processing Record 36 of Set 12 | baruun-urt
# Processing Record 37 of Set 12 | show low
# Processing Record 38 of Set 12 | bondo
# Processing Record 39 of Set 12 | asau
# Processing Record 40 of Set 12 | morehead
# Processing Record 41 of Set 12 | paamiut
# Processing Record 42 of Set 12 | saint-augustin
# Processing Record 43 of Set 12 | bonavista
# Processing Record 44 of Set 12 | teya
# Processing Record 45 of Set 12 | horsham
# Processing Record 46 of Set 12 | isakly
# Processing Record 47 of Set 12 | palembang
# Processing Record 48 of Set 12 | qiongshan
# Processing Record 49 of Set 12 | hurricane
# Processing Record 50 of Set 12 | sehithwa
# Processing Record 1 of Set 13 | muros
# Processing Record 2 of Set 13 | katherine
# Processing Record 3 of Set 13 | agadez
# Processing Record 4 of Set 13 | langenburg
# Processing Record 5 of Set 13 | biu
# Processing Record 6 of Set 13 | pontianak
# Processing Record 7 of Set 13 | adrar
# Processing Record 8 of Set 13 | le vauclin
# Processing Record 9 of Set 13 | aksu
# Processing Record 10 of Set 13 | albina
# Processing Record 11 of Set 13 | nome
# Processing Record 12 of Set 13 | nishihara
# Processing Record 13 of Set 13 | kupino
# Processing Record 14 of Set 13 | edson
# Processing Record 15 of Set 13 | mahanoro
# Processing Record 16 of Set 13 | phan rang
# City not found. Skipping...
# Processing Record 17 of Set 13 | imeni poliny osipenko
# Processing Record 18 of Set 13 | adre
# Processing Record 19 of Set 13 | cap malheureux
# Processing Record 20 of Set 13 | bandarbeyla
# Processing Record 21 of Set 13 | vilhena
# Processing Record 22 of Set 13 | saint-paul
# Processing Record 23 of Set 13 | tarimbaro
# Processing Record 24 of Set 13 | anloga
# Processing Record 25 of Set 13 | tomatlan
# Processing Record 26 of Set 13 | berlevag
# Processing Record 27 of Set 13 | ardakan
# Processing Record 28 of Set 13 | rocha
# Processing Record 29 of Set 13 | vikulovo
# Processing Record 30 of Set 13 | gat
# Processing Record 31 of Set 13 | college
# Processing Record 32 of Set 13 | dongsheng
# Processing Record 33 of Set 13 | matara
# Processing Record 34 of Set 13 | nenjiang
# Processing Record 35 of Set 13 | kavos
# Processing Record 36 of Set 13 | peoria
# Processing Record 37 of Set 13 | pontes e lacerda
# Processing Record 38 of Set 13 | sao sebastiao
# Processing Record 39 of Set 13 | massakory
# Processing Record 40 of Set 13 | banjar
# Processing Record 41 of Set 13 | cojumatlan
# City not found. Skipping...
# Processing Record 42 of Set 13 | itoman
# Processing Record 43 of Set 13 | dauriya
# Processing Record 44 of Set 13 | avera
# Processing Record 45 of Set 13 | dalbandin
# Processing Record 46 of Set 13 | yerbogachen
# Processing Record 47 of Set 13 | namatanai
# Processing Record 48 of Set 13 | andros town
# Processing Record 49 of Set 13 | kuruman
# Processing Record 50 of Set 13 | zatoka
# Processing Record 1 of Set 14 | tocopilla
# Processing Record 2 of Set 14 | ust-barguzin
# Processing Record 3 of Set 14 | gamba
# Processing Record 4 of Set 14 | hualmay
# Processing Record 5 of Set 14 | capao da canoa
# Processing Record 6 of Set 14 | samarkand
# Processing Record 7 of Set 14 | birao
# Processing Record 8 of Set 14 | axim
# Processing Record 9 of Set 14 | kingaroy
# Processing Record 10 of Set 14 | tankhoy
# Processing Record 11 of Set 14 | angangxi
# City not found. Skipping...
# Processing Record 12 of Set 14 | lavumisa
# Processing Record 13 of Set 14 | andevoranto
# City not found. Skipping...
# Processing Record 14 of Set 14 | bose
# Processing Record 15 of Set 14 | galle
# Processing Record 16 of Set 14 | hirara
# Processing Record 17 of Set 14 | nuevo progreso
# Processing Record 18 of Set 14 | okhotsk
# Processing Record 19 of Set 14 | chandbali
# Processing Record 20 of Set 14 | puerto leguizamo
# Processing Record 21 of Set 14 | gainesville
# Processing Record 22 of Set 14 | tidore
# City not found. Skipping...
# Processing Record 23 of Set 14 | novoagansk
# Processing Record 24 of Set 14 | katete
# Processing Record 25 of Set 14 | iralaya
# Processing Record 26 of Set 14 | santa isabel do rio negro
# Processing Record 27 of Set 14 | diego de almagro
# Processing Record 28 of Set 14 | watertown
# Processing Record 29 of Set 14 | port hedland
# Processing Record 30 of Set 14 | horodnytsya
# Processing Record 31 of Set 14 | holbeach
# Processing Record 32 of Set 14 | tautira
# Processing Record 33 of Set 14 | saquarema
# Processing Record 34 of Set 14 | dingle
# Processing Record 35 of Set 14 | teluknaga
# Processing Record 36 of Set 14 | kupang
# Processing Record 37 of Set 14 | bireun
# Processing Record 38 of Set 14 | eskasem
# City not found. Skipping...
# Processing Record 39 of Set 14 | magway
# Processing Record 40 of Set 14 | buckeye
# Processing Record 41 of Set 14 | coolum beach
# Processing Record 42 of Set 14 | barcelos
# Processing Record 43 of Set 14 | porto walter
# Processing Record 44 of Set 14 | izumo
# Processing Record 45 of Set 14 | bure
# Processing Record 46 of Set 14 | verkhnetulomskiy
# Processing Record 47 of Set 14 | lgov
# Processing Record 48 of Set 14 | valparaiso
# Processing Record 49 of Set 14 | redlands
# Processing Record 50 of Set 14 | yarada
# Processing Record 1 of Set 15 | inuvik
# Processing Record 2 of Set 15 | katakwi
# Processing Record 3 of Set 15 | lanzhou
# Processing Record 4 of Set 15 | hervey bay
# Processing Record 5 of Set 15 | darlowo
# Processing Record 6 of Set 15 | kasama
# Processing Record 7 of Set 15 | hobyo
# Processing Record 8 of Set 15 | batagay
# Processing Record 9 of Set 15 | vila velha
# Processing Record 10 of Set 15 | cusset
# Processing Record 11 of Set 15 | kisangani
# Processing Record 12 of Set 15 | beloha
# Processing Record 13 of Set 15 | vila do maio
# Processing Record 14 of Set 15 | north bend
# Processing Record 15 of Set 15 | poggibonsi
# Processing Record 16 of Set 15 | caucaia
# Processing Record 17 of Set 15 | turbat
# Processing Record 18 of Set 15 | jaumave
# Processing Record 19 of Set 15 | brae
# Processing Record 20 of Set 15 | wahran
# City not found. Skipping...
# Processing Record 21 of Set 15 | cairns
# Processing Record 22 of Set 15 | omboue
# Processing Record 23 of Set 15 | deputatskiy
# Processing Record 24 of Set 15 | chegdomyn
# Processing Record 25 of Set 15 | richards bay
# Processing Record 26 of Set 15 | tecoanapa
# Processing Record 27 of Set 15 | nioro
# Processing Record 28 of Set 15 | baghdad
# Processing Record 29 of Set 15 | lovington
# Processing Record 30 of Set 15 | boa vista
# Processing Record 31 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 32 of Set 15 | vao
# Processing Record 33 of Set 15 | morant bay
# Processing Record 34 of Set 15 | williston
# Processing Record 35 of Set 15 | kedougou
# Processing Record 36 of Set 15 | ishigaki
# Processing Record 37 of Set 15 | san andres
# Processing Record 38 of Set 15 | mesetas
# Processing Record 39 of Set 15 | chatellerault
# Processing Record 40 of Set 15 | tromso
# Processing Record 41 of Set 15 | akhmeta
# Processing Record 42 of Set 15 | hwange
# Processing Record 43 of Set 15 | egvekinot
# Processing Record 44 of Set 15 | verkhovazhye
# Processing Record 45 of Set 15 | yei
# Processing Record 46 of Set 15 | rottingdean
# Processing Record 47 of Set 15 | erdemli
# Processing Record 48 of Set 15 | dubbo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Punta Arenas      CL -53.1500  -70.9167     55.51        62          75
# 1       Hermanus      ZA -34.4187   19.2345     77.81        77           7
# 2  Sioux Lookout      CA  50.1001  -91.9170     -5.42        71         100
# 3      Cape Town      ZA -33.9258   18.4232     77.27        52           0
# 4        Margate      GB  51.3813    1.3862     46.96        55          32
# 5        Mataura      NZ -46.1927  168.8643     51.48        86         100
# 6        Ushuaia      AR -54.8000  -68.3000     53.26        58          75
# 7      Batsfjord      NO  70.6345   29.7185     33.73        86          75
# 8    Port Alfred      ZA -33.5906   26.8910     73.45        72           1
# 9  Makakilo City      US  21.3469 -158.0858     63.61        83           0
#
#    Wind Speed Current Description
# 0       28.77       broken clouds
# 1        6.82           clear sky
# 2       13.80     overcast clouds
# 3       18.41           clear sky
# 4        1.01    scattered clouds
# 5        2.53     overcast clouds
# 6       10.36       broken clouds
# 7       27.63       broken clouds
# 8        6.53           clear sky
# 9        4.61           clear sky

# %%
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label='City_ID')
